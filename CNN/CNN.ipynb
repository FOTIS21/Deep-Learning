# %% [markdown]
# <a href="https://colab.research.google.com/github/FOTIS21/Deep-Learning/blob/main/ffNN_Deep_Narrow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
# import kagglehub
# kagglehub.login()

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

# fotischatz_xview_dataset_path = kagglehub.dataset_download('fotischatz/xview-dataset')
#
# print('Data source import complete.')

# %% [markdown]
# <a href="https://colab.research.google.com/github/FOTIS21/Deep-Learning/blob/main/ffNN_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
# import kagglehub
# kagglehub.login()

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
#
# fotischatz_xview_dataset_path = kagglehub.dataset_download('fotischatz/xview-dataset')
#
# print('Data source import complete.')

# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1:
# - Alumno 2:
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
import tensorflow as tf
import os
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
import warnings
import rasterio
import numpy as np

import os

if os.path.exists("/kaggle/input"):
    print("Running on Kaggle")
    BASE_PATH = "/kaggle/input/datasets/fotischatz/xview-dataset/xview_recognition"
else:
    print("Running locally")
    BASE_PATH = "./xview_recognition"

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    if "xview_recognition/" in filename:
        filename = filename.split("xview_recognition/")[-1]

    full_path = os.path.join(BASE_PATH, filename)

    src_raster = rasterio.open(full_path, 'r')# RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img
# Out:
# Running on Kaggle

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = os.path.join(BASE_PATH, 'xview_ann_train.json')
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 16871
# Number of validation images: 1875

# %%
# Load architecture
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GlobalAveragePooling2D, RandomFlip, RandomRotation, RandomZoom, Resizing, Dense, Flatten, Dropout, BatchNormalization, Rescaling, LeakyReLU, Conv2D, MaxPooling2D, Activation
from tensorflow.keras import regularizers
from tensorflow.keras.initializers import HeNormal


print('Load CNN model')

model = Sequential()

# Input preprocessing
model.add(Rescaling(1./255, input_shape=(224,224,3)))
model.add(RandomFlip("horizontal"))
model.add(RandomFlip("vertical"))
model.add(RandomRotation(0.05))
model.add(RandomZoom(0.1))

# Conv Block 1
model.add(Conv2D(32, (3,3), padding='same', kernel_initializer=HeNormal()))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))

# Conv Block 2
model.add(Conv2D(64, (3,3), padding='same', kernel_initializer=HeNormal()))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))

# Conv Block 3
model.add(Conv2D(128, (3,3), padding='same', kernel_initializer=HeNormal()))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))

# Conv Block 4
model.add(Conv2D(256, (3,3), padding='same', kernel_initializer=HeNormal()))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))

# Fully connected
model.add(Flatten())

model.add(Dense(256, kernel_initializer=HeNormal()))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(128, kernel_initializer=HeNormal()))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Output
model.add(Dense(13, activation='softmax'))

model.summary()
# Out:
# Load CNN model
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# I0000 00:00:1773011905.876695      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_flip (RandomFlip)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_flip_1 (RandomFlip)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 224, 224, 3)    │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom (RandomZoom)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    12,845,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,271,757 (50.63 MB)
#  Trainable params: 13,270,029 (50.62 MB)
#  Non-trainable params: 1,728 (6.75 KB)

# %%
from tensorflow.keras.optimizers import Adam, SGD

# Learning rate is changed to 0.001
# opt = SGD(learning_rate=0.005, momentum=0.9)
# opt = Adam(learning_rate=1e-4)
opt = Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=8, verbose=1)
early_stop = EarlyStopping('val_accuracy', patience=20, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
from PIL import Image

from PIL import Image
import numpy as np

def generator_images(objs, batch_size, do_shuffle=False):

    while True:

        if do_shuffle:
            np.random.shuffle(objs)

        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]

        for group in groups:

            images = []
            labels = []

            for (filename, obj) in group:

                img = load_geoimage(filename)
                img = tf.image.resize(img, (224,224))   # resize fix
                images.append(img)

                probabilities = np.zeros(len(categories))

                category_index = list(categories.values()).index(obj.category)
                probabilities[category_index] = 1

                labels.append(probabilities)

            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)

            yield images, labels

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 64
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model')
epochs = 100
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# I0000 00:00:1773011925.228558     132 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2220 - loss: 2.5004
# Epoch 1: val_accuracy improved from -inf to 0.18720, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 1127s 4s/step - accuracy: 0.2222 - loss: 2.4994 - val_accuracy: 0.1872 - val_loss: 2.8127 - learning_rate: 1.0000e-04
# Epoch 2/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.4014 - loss: 1.8735
# Epoch 2: val_accuracy improved from 0.18720 to 0.34453, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 158s 599ms/step - accuracy: 0.4014 - loss: 1.8734 - val_accuracy: 0.3445 - val_loss: 2.0536 - learning_rate: 1.0000e-04
# Epoch 3/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.4503 - loss: 1.6801
# Epoch 3: val_accuracy improved from 0.34453 to 0.52373, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 154s 587ms/step - accuracy: 0.4503 - loss: 1.6800 - val_accuracy: 0.5237 - val_loss: 1.4467 - learning_rate: 1.0000e-04
# Epoch 4/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - accuracy: 0.4731 - loss: 1.5948
# Epoch 4: val_accuracy improved from 0.52373 to 0.52533, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 160s 608ms/step - accuracy: 0.4731 - loss: 1.5948 - val_accuracy: 0.5253 - val_loss: 1.4078 - learning_rate: 1.0000e-04
# Epoch 5/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.5066 - loss: 1.4934
# Epoch 5: val_accuracy improved from 0.52533 to 0.54560, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 157s 597ms/step - accuracy: 0.5066 - loss: 1.4934 - val_accuracy: 0.5456 - val_loss: 1.3708 - learning_rate: 1.0000e-04
# Epoch 6/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.5119 - loss: 1.4646
# Epoch 6: val_accuracy improved from 0.54560 to 0.57067, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 563ms/step - accuracy: 0.5119 - loss: 1.4645 - val_accuracy: 0.5707 - val_loss: 1.2824 - learning_rate: 1.0000e-04
# Epoch 7/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.5322 - loss: 1.3988
# Epoch 7: val_accuracy improved from 0.57067 to 0.57547, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 562ms/step - accuracy: 0.5322 - loss: 1.3988 - val_accuracy: 0.5755 - val_loss: 1.2362 - learning_rate: 1.0000e-04
# Epoch 8/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.5505 - loss: 1.3549
# Epoch 8: val_accuracy improved from 0.57547 to 0.61333, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 561ms/step - accuracy: 0.5505 - loss: 1.3550 - val_accuracy: 0.6133 - val_loss: 1.1743 - learning_rate: 1.0000e-04
# Epoch 9/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.5552 - loss: 1.3273
# Epoch 9: val_accuracy did not improve from 0.61333
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 570ms/step - accuracy: 0.5552 - loss: 1.3273 - val_accuracy: 0.5840 - val_loss: 1.2537 - learning_rate: 1.0000e-04
# Epoch 10/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.5683 - loss: 1.2747
# Epoch 10: val_accuracy improved from 0.61333 to 0.61920, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 152s 576ms/step - accuracy: 0.5683 - loss: 1.2748 - val_accuracy: 0.6192 - val_loss: 1.1563 - learning_rate: 1.0000e-04
# Epoch 11/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.5778 - loss: 1.2520
# Epoch 11: val_accuracy did not improve from 0.61920
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 568ms/step - accuracy: 0.5778 - loss: 1.2520 - val_accuracy: 0.6011 - val_loss: 1.1608 - learning_rate: 1.0000e-04
# Epoch 12/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.5866 - loss: 1.2454
# Epoch 12: val_accuracy improved from 0.61920 to 0.62453, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 568ms/step - accuracy: 0.5866 - loss: 1.2454 - val_accuracy: 0.6245 - val_loss: 1.1239 - learning_rate: 1.0000e-04
# Epoch 13/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.5992 - loss: 1.1936
# Epoch 13: val_accuracy did not improve from 0.62453
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 147s 558ms/step - accuracy: 0.5992 - loss: 1.1937 - val_accuracy: 0.6053 - val_loss: 1.1383 - learning_rate: 1.0000e-04
# Epoch 14/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.5933 - loss: 1.2151
# Epoch 14: val_accuracy did not improve from 0.62453
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 570ms/step - accuracy: 0.5933 - loss: 1.2150 - val_accuracy: 0.6096 - val_loss: 1.1033 - learning_rate: 1.0000e-04
# Epoch 15/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.5937 - loss: 1.1880
# Epoch 15: val_accuracy did not improve from 0.62453
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 571ms/step - accuracy: 0.5937 - loss: 1.1880 - val_accuracy: 0.6053 - val_loss: 1.1680 - learning_rate: 1.0000e-04
# Epoch 16/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.6043 - loss: 1.1814
# Epoch 16: val_accuracy did not improve from 0.62453
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 568ms/step - accuracy: 0.6043 - loss: 1.1815 - val_accuracy: 0.6080 - val_loss: 1.1280 - learning_rate: 1.0000e-04
# Epoch 17/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.6078 - loss: 1.1564
# Epoch 17: val_accuracy improved from 0.62453 to 0.63787, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 151s 573ms/step - accuracy: 0.6078 - loss: 1.1564 - val_accuracy: 0.6379 - val_loss: 1.0432 - learning_rate: 1.0000e-04
# Epoch 18/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.6120 - loss: 1.1413
# Epoch 18: val_accuracy did not improve from 0.63787
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 563ms/step - accuracy: 0.6120 - loss: 1.1413 - val_accuracy: 0.6331 - val_loss: 1.0519 - learning_rate: 1.0000e-04
# Epoch 19/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.6180 - loss: 1.1433
# Epoch 19: val_accuracy improved from 0.63787 to 0.64960, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 561ms/step - accuracy: 0.6180 - loss: 1.1433 - val_accuracy: 0.6496 - val_loss: 1.0305 - learning_rate: 1.0000e-04
# Epoch 20/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.6215 - loss: 1.1097
# Epoch 20: val_accuracy did not improve from 0.64960
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 147s 557ms/step - accuracy: 0.6215 - loss: 1.1097 - val_accuracy: 0.6485 - val_loss: 1.0194 - learning_rate: 1.0000e-04
# Epoch 21/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.6290 - loss: 1.0947
# Epoch 21: val_accuracy did not improve from 0.64960
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 566ms/step - accuracy: 0.6290 - loss: 1.0947 - val_accuracy: 0.6347 - val_loss: 1.0855 - learning_rate: 1.0000e-04
# Epoch 22/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.6252 - loss: 1.1008
# Epoch 22: val_accuracy did not improve from 0.64960
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 152s 578ms/step - accuracy: 0.6252 - loss: 1.1008 - val_accuracy: 0.6389 - val_loss: 1.0282 - learning_rate: 1.0000e-04
# Epoch 23/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.6301 - loss: 1.0918
# Epoch 23: val_accuracy improved from 0.64960 to 0.66560, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 153s 581ms/step - accuracy: 0.6302 - loss: 1.0918 - val_accuracy: 0.6656 - val_loss: 0.9925 - learning_rate: 1.0000e-04
# Epoch 24/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.6442 - loss: 1.0647
# Epoch 24: val_accuracy improved from 0.66560 to 0.66773, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 569ms/step - accuracy: 0.6441 - loss: 1.0648 - val_accuracy: 0.6677 - val_loss: 0.9912 - learning_rate: 1.0000e-04
# Epoch 25/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.6380 - loss: 1.0800
# Epoch 25: val_accuracy did not improve from 0.66773
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 564ms/step - accuracy: 0.6380 - loss: 1.0799 - val_accuracy: 0.6603 - val_loss: 0.9913 - learning_rate: 1.0000e-04
# Epoch 26/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.6470 - loss: 1.0582
# Epoch 26: val_accuracy did not improve from 0.66773
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 567ms/step - accuracy: 0.6470 - loss: 1.0582 - val_accuracy: 0.6427 - val_loss: 1.0380 - learning_rate: 1.0000e-04
# Epoch 27/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.6476 - loss: 1.0390
# Epoch 27: val_accuracy did not improve from 0.66773
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 567ms/step - accuracy: 0.6477 - loss: 1.0390 - val_accuracy: 0.6501 - val_loss: 1.0318 - learning_rate: 1.0000e-04
# Epoch 28/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.6561 - loss: 1.0398
# Epoch 28: val_accuracy did not improve from 0.66773
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 567ms/step - accuracy: 0.6561 - loss: 1.0397 - val_accuracy: 0.6613 - val_loss: 0.9955 - learning_rate: 1.0000e-04
# Epoch 29/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.6552 - loss: 1.0288
# Epoch 29: val_accuracy improved from 0.66773 to 0.67360, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 151s 575ms/step - accuracy: 0.6552 - loss: 1.0288 - val_accuracy: 0.6736 - val_loss: 0.9583 - learning_rate: 1.0000e-04
# Epoch 30/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.6541 - loss: 1.0222
# Epoch 30: val_accuracy improved from 0.67360 to 0.67627, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 153s 580ms/step - accuracy: 0.6541 - loss: 1.0222 - val_accuracy: 0.6763 - val_loss: 0.9534 - learning_rate: 1.0000e-04
# Epoch 31/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.6620 - loss: 1.0179
# Epoch 31: val_accuracy did not improve from 0.67627
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 151s 574ms/step - accuracy: 0.6620 - loss: 1.0179 - val_accuracy: 0.6725 - val_loss: 0.9350 - learning_rate: 1.0000e-04
# Epoch 32/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.6637 - loss: 0.9957
# Epoch 32: val_accuracy did not improve from 0.67627
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 565ms/step - accuracy: 0.6637 - loss: 0.9957 - val_accuracy: 0.6688 - val_loss: 0.9428 - learning_rate: 1.0000e-04
# Epoch 33/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.6641 - loss: 0.9876
# Epoch 33: val_accuracy did not improve from 0.67627
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 563ms/step - accuracy: 0.6641 - loss: 0.9876 - val_accuracy: 0.6736 - val_loss: 0.9634 - learning_rate: 1.0000e-04
# Epoch 34/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.6630 - loss: 0.9760
# Epoch 34: val_accuracy did not improve from 0.67627
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 147s 559ms/step - accuracy: 0.6630 - loss: 0.9761 - val_accuracy: 0.6469 - val_loss: 1.0143 - learning_rate: 1.0000e-04
# Epoch 35/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.6633 - loss: 0.9848
# Epoch 35: val_accuracy did not improve from 0.67627
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 147s 556ms/step - accuracy: 0.6633 - loss: 0.9849 - val_accuracy: 0.6629 - val_loss: 0.9970 - learning_rate: 1.0000e-04
# Epoch 36/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.6736 - loss: 0.9799
# Epoch 36: val_accuracy did not improve from 0.67627
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 147s 556ms/step - accuracy: 0.6735 - loss: 0.9800 - val_accuracy: 0.6587 - val_loss: 0.9688 - learning_rate: 1.0000e-04
# Epoch 37/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.6746 - loss: 0.9621
# Epoch 37: val_accuracy improved from 0.67627 to 0.68160, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 568ms/step - accuracy: 0.6746 - loss: 0.9622 - val_accuracy: 0.6816 - val_loss: 0.9459 - learning_rate: 1.0000e-04
# Epoch 38/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.6718 - loss: 0.9667
# Epoch 38: val_accuracy improved from 0.68160 to 0.68213, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 563ms/step - accuracy: 0.6718 - loss: 0.9666 - val_accuracy: 0.6821 - val_loss: 0.9428 - learning_rate: 1.0000e-04
# Epoch 39/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.6755 - loss: 0.9635
# Epoch 39: val_accuracy did not improve from 0.68213
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 146s 555ms/step - accuracy: 0.6755 - loss: 0.9635 - val_accuracy: 0.6725 - val_loss: 0.9836 - learning_rate: 1.0000e-04
# Epoch 40/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.6767 - loss: 0.9571
# Epoch 40: val_accuracy did not improve from 0.68213
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 568ms/step - accuracy: 0.6767 - loss: 0.9571 - val_accuracy: 0.6773 - val_loss: 0.9497 - learning_rate: 1.0000e-04
# Epoch 41/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.6859 - loss: 0.9299
# Epoch 41: val_accuracy did not improve from 0.68213
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 563ms/step - accuracy: 0.6859 - loss: 0.9300 - val_accuracy: 0.6821 - val_loss: 0.9294 - learning_rate: 1.0000e-04
# Epoch 42/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.6821 - loss: 0.9395
# Epoch 42: val_accuracy did not improve from 0.68213
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 147s 558ms/step - accuracy: 0.6821 - loss: 0.9396 - val_accuracy: 0.6667 - val_loss: 0.9365 - learning_rate: 1.0000e-04
# Epoch 43/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.6917 - loss: 0.9191
# Epoch 43: val_accuracy improved from 0.68213 to 0.68747, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 568ms/step - accuracy: 0.6916 - loss: 0.9191 - val_accuracy: 0.6875 - val_loss: 0.9038 - learning_rate: 1.0000e-04
# Epoch 44/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - accuracy: 0.6843 - loss: 0.9361
# Epoch 44: val_accuracy did not improve from 0.68747
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 165s 628ms/step - accuracy: 0.6843 - loss: 0.9361 - val_accuracy: 0.6811 - val_loss: 0.9121 - learning_rate: 1.0000e-04
# Epoch 45/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.6895 - loss: 0.9135
# Epoch 45: val_accuracy did not improve from 0.68747
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 563ms/step - accuracy: 0.6895 - loss: 0.9136 - val_accuracy: 0.6763 - val_loss: 0.9283 - learning_rate: 1.0000e-04
# Epoch 46/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.6865 - loss: 0.9234
# Epoch 46: val_accuracy did not improve from 0.68747
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 565ms/step - accuracy: 0.6865 - loss: 0.9234 - val_accuracy: 0.6747 - val_loss: 0.9505 - learning_rate: 1.0000e-04
# Epoch 47/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.6857 - loss: 0.9299
# Epoch 47: val_accuracy improved from 0.68747 to 0.68960, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 564ms/step - accuracy: 0.6858 - loss: 0.9299 - val_accuracy: 0.6896 - val_loss: 0.9025 - learning_rate: 1.0000e-04
# Epoch 48/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.6934 - loss: 0.8979
# Epoch 48: val_accuracy did not improve from 0.68960
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 147s 559ms/step - accuracy: 0.6934 - loss: 0.8979 - val_accuracy: 0.6811 - val_loss: 0.9152 - learning_rate: 1.0000e-04
# Epoch 49/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.6929 - loss: 0.9003
# Epoch 49: val_accuracy did not improve from 0.68960
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 564ms/step - accuracy: 0.6929 - loss: 0.9004 - val_accuracy: 0.6827 - val_loss: 0.9174 - learning_rate: 1.0000e-04
# Epoch 50/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.6997 - loss: 0.8871
# Epoch 50: val_accuracy improved from 0.68960 to 0.69440, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 152s 577ms/step - accuracy: 0.6996 - loss: 0.8872 - val_accuracy: 0.6944 - val_loss: 0.8855 - learning_rate: 1.0000e-04
# Epoch 51/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.6992 - loss: 0.8907
# Epoch 51: val_accuracy did not improve from 0.69440
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 563ms/step - accuracy: 0.6992 - loss: 0.8907 - val_accuracy: 0.6901 - val_loss: 0.8920 - learning_rate: 1.0000e-04
# Epoch 52/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.6938 - loss: 0.8942
# Epoch 52: val_accuracy did not improve from 0.69440
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 571ms/step - accuracy: 0.6938 - loss: 0.8942 - val_accuracy: 0.6816 - val_loss: 0.8959 - learning_rate: 1.0000e-04
# Epoch 53/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7063 - loss: 0.8734
# Epoch 53: val_accuracy did not improve from 0.69440
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 151s 574ms/step - accuracy: 0.7063 - loss: 0.8735 - val_accuracy: 0.6853 - val_loss: 0.9099 - learning_rate: 1.0000e-04
# Epoch 54/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.6988 - loss: 0.8885
# Epoch 54: val_accuracy did not improve from 0.69440
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 154s 587ms/step - accuracy: 0.6989 - loss: 0.8884 - val_accuracy: 0.6848 - val_loss: 0.9137 - learning_rate: 1.0000e-04
# Epoch 55/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.7017 - loss: 0.8799
# Epoch 55: val_accuracy did not improve from 0.69440
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 568ms/step - accuracy: 0.7017 - loss: 0.8799 - val_accuracy: 0.6811 - val_loss: 0.9123 - learning_rate: 1.0000e-04
# Epoch 56/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.7029 - loss: 0.8819
# Epoch 56: val_accuracy did not improve from 0.69440
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 147s 559ms/step - accuracy: 0.7029 - loss: 0.8818 - val_accuracy: 0.6944 - val_loss: 0.8788 - learning_rate: 1.0000e-04
# Epoch 57/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.7110 - loss: 0.8564
# Epoch 57: val_accuracy did not improve from 0.69440
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 561ms/step - accuracy: 0.7110 - loss: 0.8565 - val_accuracy: 0.6827 - val_loss: 0.9364 - learning_rate: 1.0000e-04
# Epoch 58/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.7104 - loss: 0.8494
# Epoch 58: val_accuracy did not improve from 0.69440
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 147s 559ms/step - accuracy: 0.7104 - loss: 0.8495 - val_accuracy: 0.6901 - val_loss: 0.9278 - learning_rate: 1.0000e-04
# Epoch 59/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.7154 - loss: 0.8364
# Epoch 59: val_accuracy improved from 0.69440 to 0.70453, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 152s 579ms/step - accuracy: 0.7154 - loss: 0.8364 - val_accuracy: 0.7045 - val_loss: 0.8592 - learning_rate: 1.0000e-05
# Epoch 60/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.7223 - loss: 0.8188
# Epoch 60: val_accuracy did not improve from 0.70453
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 147s 560ms/step - accuracy: 0.7223 - loss: 0.8188 - val_accuracy: 0.7013 - val_loss: 0.8573 - learning_rate: 1.0000e-05
# Epoch 61/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.7221 - loss: 0.8162
# Epoch 61: val_accuracy did not improve from 0.70453
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 563ms/step - accuracy: 0.7221 - loss: 0.8162 - val_accuracy: 0.7024 - val_loss: 0.8506 - learning_rate: 1.0000e-05
# Epoch 62/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.7244 - loss: 0.8201
# Epoch 62: val_accuracy did not improve from 0.70453
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 153s 580ms/step - accuracy: 0.7244 - loss: 0.8201 - val_accuracy: 0.7029 - val_loss: 0.8500 - learning_rate: 1.0000e-05
# Epoch 63/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.7209 - loss: 0.8095
# Epoch 63: val_accuracy did not improve from 0.70453
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 155s 587ms/step - accuracy: 0.7209 - loss: 0.8095 - val_accuracy: 0.7003 - val_loss: 0.8475 - learning_rate: 1.0000e-05
# Epoch 64/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.7255 - loss: 0.8063
# Epoch 64: val_accuracy did not improve from 0.70453
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 146s 555ms/step - accuracy: 0.7255 - loss: 0.8063 - val_accuracy: 0.7003 - val_loss: 0.8501 - learning_rate: 1.0000e-05
# Epoch 65/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.7270 - loss: 0.8032
# Epoch 65: val_accuracy did not improve from 0.70453
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 567ms/step - accuracy: 0.7270 - loss: 0.8032 - val_accuracy: 0.7035 - val_loss: 0.8508 - learning_rate: 1.0000e-05
# Epoch 66/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.7333 - loss: 0.8003
# Epoch 66: val_accuracy improved from 0.70453 to 0.70667, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 565ms/step - accuracy: 0.7333 - loss: 0.8003 - val_accuracy: 0.7067 - val_loss: 0.8512 - learning_rate: 1.0000e-05
# Epoch 67/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.7271 - loss: 0.7971
# Epoch 67: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 161s 611ms/step - accuracy: 0.7271 - loss: 0.7971 - val_accuracy: 0.7056 - val_loss: 0.8469 - learning_rate: 1.0000e-05
# Epoch 68/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.7241 - loss: 0.8211
# Epoch 68: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 161s 611ms/step - accuracy: 0.7241 - loss: 0.8210 - val_accuracy: 0.7024 - val_loss: 0.8487 - learning_rate: 1.0000e-05
# Epoch 69/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.7309 - loss: 0.7904
# Epoch 69: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 156s 592ms/step - accuracy: 0.7309 - loss: 0.7904 - val_accuracy: 0.7019 - val_loss: 0.8506 - learning_rate: 1.0000e-05
# Epoch 70/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.7371 - loss: 0.7791
# Epoch 70: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 569ms/step - accuracy: 0.7370 - loss: 0.7792 - val_accuracy: 0.7029 - val_loss: 0.8493 - learning_rate: 1.0000e-05
# Epoch 71/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.7312 - loss: 0.7966
# Epoch 71: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 145s 551ms/step - accuracy: 0.7312 - loss: 0.7966 - val_accuracy: 0.7061 - val_loss: 0.8455 - learning_rate: 1.0000e-05
# Epoch 72/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.7343 - loss: 0.7887
# Epoch 72: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 563ms/step - accuracy: 0.7343 - loss: 0.7887 - val_accuracy: 0.7019 - val_loss: 0.8490 - learning_rate: 1.0000e-05
# Epoch 73/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.7276 - loss: 0.7830
# Epoch 73: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 562ms/step - accuracy: 0.7276 - loss: 0.7831 - val_accuracy: 0.7013 - val_loss: 0.8483 - learning_rate: 1.0000e-05
# Epoch 74/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.7308 - loss: 0.7935
# Epoch 74: val_accuracy did not improve from 0.70667
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 147s 558ms/step - accuracy: 0.7308 - loss: 0.7935 - val_accuracy: 0.7061 - val_loss: 0.8442 - learning_rate: 1.0000e-05
# Epoch 75/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.7290 - loss: 0.7992
# Epoch 75: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 146s 555ms/step - accuracy: 0.7291 - loss: 0.7991 - val_accuracy: 0.7056 - val_loss: 0.8441 - learning_rate: 1.0000e-06
# Epoch 76/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.7293 - loss: 0.7934
# Epoch 76: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 151s 573ms/step - accuracy: 0.7293 - loss: 0.7934 - val_accuracy: 0.7061 - val_loss: 0.8434 - learning_rate: 1.0000e-06
# Epoch 77/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.7335 - loss: 0.7885
# Epoch 77: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 569ms/step - accuracy: 0.7335 - loss: 0.7885 - val_accuracy: 0.7051 - val_loss: 0.8441 - learning_rate: 1.0000e-06
# Epoch 78/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.7288 - loss: 0.7953
# Epoch 78: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 151s 573ms/step - accuracy: 0.7288 - loss: 0.7953 - val_accuracy: 0.7045 - val_loss: 0.8443 - learning_rate: 1.0000e-06
# Epoch 79/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.7323 - loss: 0.7737
# Epoch 79: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 568ms/step - accuracy: 0.7323 - loss: 0.7737 - val_accuracy: 0.7051 - val_loss: 0.8442 - learning_rate: 1.0000e-06
# Epoch 80/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.7314 - loss: 0.7904
# Epoch 80: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 569ms/step - accuracy: 0.7314 - loss: 0.7904 - val_accuracy: 0.7067 - val_loss: 0.8426 - learning_rate: 1.0000e-06
# Epoch 81/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.7323 - loss: 0.7819
# Epoch 81: val_accuracy did not improve from 0.70667
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 566ms/step - accuracy: 0.7323 - loss: 0.7819 - val_accuracy: 0.7056 - val_loss: 0.8420 - learning_rate: 1.0000e-06
# Epoch 82/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.7301 - loss: 0.7875
# Epoch 82: val_accuracy improved from 0.70667 to 0.70720, saving model to model.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 151s 575ms/step - accuracy: 0.7301 - loss: 0.7875 - val_accuracy: 0.7072 - val_loss: 0.8432 - learning_rate: 1.0000e-06
# Epoch 83/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.7277 - loss: 0.7911
# Epoch 83: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 146s 556ms/step - accuracy: 0.7278 - loss: 0.7911 - val_accuracy: 0.7051 - val_loss: 0.8422 - learning_rate: 1.0000e-06
# Epoch 84/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.7334 - loss: 0.7833
# Epoch 84: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 152s 579ms/step - accuracy: 0.7334 - loss: 0.7833 - val_accuracy: 0.7051 - val_loss: 0.8430 - learning_rate: 1.0000e-06
# Epoch 85/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.7247 - loss: 0.7962
# Epoch 85: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 569ms/step - accuracy: 0.7247 - loss: 0.7961 - val_accuracy: 0.7067 - val_loss: 0.8428 - learning_rate: 1.0000e-06
# Epoch 86/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.7354 - loss: 0.7850
# Epoch 86: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 151s 572ms/step - accuracy: 0.7354 - loss: 0.7850 - val_accuracy: 0.7056 - val_loss: 0.8429 - learning_rate: 1.0000e-06
# Epoch 87/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.7305 - loss: 0.7860
# Epoch 87: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 155s 590ms/step - accuracy: 0.7305 - loss: 0.7860 - val_accuracy: 0.7072 - val_loss: 0.8412 - learning_rate: 1.0000e-06
# Epoch 88/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.7282 - loss: 0.7957
# Epoch 88: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 153s 583ms/step - accuracy: 0.7282 - loss: 0.7957 - val_accuracy: 0.7067 - val_loss: 0.8421 - learning_rate: 1.0000e-06
# Epoch 89/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.7410 - loss: 0.7675
# Epoch 89: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 154s 586ms/step - accuracy: 0.7410 - loss: 0.7676 - val_accuracy: 0.7051 - val_loss: 0.8429 - learning_rate: 1.0000e-06
# Epoch 90/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.7463 - loss: 0.7638
# Epoch 90: val_accuracy did not improve from 0.70720
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 151s 573ms/step - accuracy: 0.7462 - loss: 0.7638 - val_accuracy: 0.7056 - val_loss: 0.8431 - learning_rate: 1.0000e-06
# Epoch 91/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.7300 - loss: 0.7890
# Epoch 91: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 154s 585ms/step - accuracy: 0.7300 - loss: 0.7890 - val_accuracy: 0.7040 - val_loss: 0.8432 - learning_rate: 1.0000e-07
# Epoch 92/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.7331 - loss: 0.7830
# Epoch 92: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 567ms/step - accuracy: 0.7331 - loss: 0.7830 - val_accuracy: 0.7051 - val_loss: 0.8433 - learning_rate: 1.0000e-07
# Epoch 93/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7333 - loss: 0.7893
# Epoch 93: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 565ms/step - accuracy: 0.7334 - loss: 0.7893 - val_accuracy: 0.7051 - val_loss: 0.8424 - learning_rate: 1.0000e-07
# Epoch 94/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.7351 - loss: 0.7711
# Epoch 94: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 151s 572ms/step - accuracy: 0.7351 - loss: 0.7711 - val_accuracy: 0.7051 - val_loss: 0.8421 - learning_rate: 1.0000e-07
# Epoch 95/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.7329 - loss: 0.7877
# Epoch 95: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 153s 581ms/step - accuracy: 0.7329 - loss: 0.7877 - val_accuracy: 0.7045 - val_loss: 0.8426 - learning_rate: 1.0000e-07
# Epoch 96/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7304 - loss: 0.7887
# Epoch 96: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 562ms/step - accuracy: 0.7304 - loss: 0.7887 - val_accuracy: 0.7040 - val_loss: 0.8429 - learning_rate: 1.0000e-07
# Epoch 97/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.7469 - loss: 0.7536
# Epoch 97: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 150s 570ms/step - accuracy: 0.7469 - loss: 0.7537 - val_accuracy: 0.7029 - val_loss: 0.8432 - learning_rate: 1.0000e-07
# Epoch 98/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.7406 - loss: 0.7750
# Epoch 98: val_accuracy did not improve from 0.70720
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 562ms/step - accuracy: 0.7406 - loss: 0.7750 - val_accuracy: 0.7051 - val_loss: 0.8429 - learning_rate: 1.0000e-07
# Epoch 99/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.7333 - loss: 0.7993
# Epoch 99: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 149s 565ms/step - accuracy: 0.7333 - loss: 0.7993 - val_accuracy: 0.7051 - val_loss: 0.8424 - learning_rate: 1.0000e-08
# Epoch 100/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.7387 - loss: 0.7813
# Epoch 100: val_accuracy did not improve from 0.70720
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 561ms/step - accuracy: 0.7387 - loss: 0.7813 - val_accuracy: 0.7051 - val_loss: 0.8428 - learning_rate: 1.0000e-08
# Best validation model: epoch 82  - val_accuracy 0.7071999907493591

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np

model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 70.720%
# Mean Recall: 70.194%
# Mean Precision: 74.280%
# > Cargo plane: Recall: 84.746% Precision: 94.340% Specificity: 99.835% Dice: 89.286%
# > Small car: Recall: 91.793% Precision: 71.226% Specificity: 92.109% Dice: 80.212%
# > Bus: Recall: 60.345% Precision: 60.345% Specificity: 95.944% Dice: 60.345%
# > Truck: Recall: 26.971% Precision: 47.445% Specificity: 95.594% Dice: 34.392%
# > Motorboat: Recall: 64.220% Precision: 66.667% Specificity: 98.018% Dice: 65.421%
# > Fishing vessel: Recall: 75.342% Precision: 80.882% Specificity: 99.279% Dice: 78.014%
# > Dump truck: Recall: 62.712% Precision: 59.200% Specificity: 97.097% Dice: 60.905%
# > Excavator: Recall: 77.778% Precision: 73.256% Specificity: 98.718% Dice: 75.449%
# > Building: Recall: 87.328% Precision: 80.253% Specificity: 94.841% Dice: 83.641%
# > Helipad: Recall: 77.778% Precision: 100.000% Specificity: 100.000% Dice: 87.500%
# > Storage tank: Recall: 63.816% Precision: 80.833% Specificity: 98.665% Dice: 71.324%
# > Shipping container: Recall: 74.074% Precision: 63.694% Specificity: 96.724% Dice: 68.493%
# > Pylon: Recall: 65.625% Precision: 87.500% Specificity: 99.837% Dice: 75.000%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
test_path = os.path.join(BASE_PATH, 'xview_test')

for (dirpath, dirnames, filenames) in os.walk(test_path):
    for filename in filenames:
        relative_path = os.path.relpath(os.path.join(dirpath, filename), BASE_PATH)
        image = GenericImage(relative_path)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
