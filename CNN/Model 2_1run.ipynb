# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1:
# - Alumno 2:
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_path = '/content/drive/MyDrive/Projects Data/xview_recognition.zip'  # Change this path
extract_path = '/content/dl_data'  # Where to extract
os.makedirs(extract_path, exist_ok=True)
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
print("Files extracted to:", extract_path)
print("Contents:", os.listdir(extract_path))
# Out:
# Files extracted to: /content/dl_data
# Contents: ['xview_recognition']

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
! pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.2.25)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.2)

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('/content/dl_data/xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = '/content/dl_data/xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 16871
# Number of validation images: 1875

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Dense, Activation, Dropout, Flatten
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, Rescaling
from tensorflow.keras.regularizers import l2
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.layers import Resizing
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Rescaling


print('Load model')
model = Sequential()

model.add(Rescaling(1./255, input_shape=(224, 224, 3)))
model.add(RandomFlip("horizontal_and_vertical"))
model.add(RandomZoom(0.15))

# 1st Block: Large 5x5 kernel
model.add(Conv2D(32, (5, 5), activation='relu', padding='same', kernel_initializer=HeNormal()))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

# 2nd Block: Standard 3x3 kernel
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer=HeNormal()))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

# Dense Classifier with L2 Regularization
from tensorflow.keras.regularizers import l2
model.add(Dense(256, activation='relu', kernel_regularizer=l2(1e-4), kernel_initializer=HeNormal()))
model.add(Dropout(0.4))
model.add(Dense(13, activation='softmax'))

model.summary()
# Out:
# Load model
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_flip_2 (RandomFlip)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom_2 (RandomZoom)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 200704)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    51,380,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 13)             │         3,341 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,405,133 (196.10 MB)
#  Trainable params: 51,404,941 (196.09 MB)
#  Non-trainable params: 192 (768.00 B)

# %%
from tensorflow.keras.optimizers import RMSprop
# Learning rate is changed to 0.001
opt = RMSprop(learning_rate=1e-4, rho=0.9)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.5, patience=5, verbose=1)
early_stop = EarlyStopping('val_accuracy', patience=10, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
def generator_images(objs, batch_size, do_shuffle=False):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                # Load image
                images.append(load_geoimage(filename).astype(np.float32))
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
    # Generators
batch_size = 32
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model')
epochs = 100
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.2413 - loss: 5.0001
# Epoch 1: val_accuracy improved from -inf to 0.28267, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 88s 156ms/step - accuracy: 0.2413 - loss: 4.9964 - val_accuracy: 0.2827 - val_loss: 2.1776 - learning_rate: 1.0000e-04
# Epoch 2/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3104 - loss: 2.2502
# Epoch 2: val_accuracy improved from 0.28267 to 0.37493, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 82s 155ms/step - accuracy: 0.3104 - loss: 2.2501 - val_accuracy: 0.3749 - val_loss: 1.9257 - learning_rate: 1.0000e-04
# Epoch 3/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3306 - loss: 2.1399
# Epoch 3: val_accuracy improved from 0.37493 to 0.38933, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 81s 154ms/step - accuracy: 0.3306 - loss: 2.1399 - val_accuracy: 0.3893 - val_loss: 1.8298 - learning_rate: 1.0000e-04
# Epoch 4/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3341 - loss: 2.0413
# Epoch 4: val_accuracy did not improve from 0.38933
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.3341 - loss: 2.0414 - val_accuracy: 0.3659 - val_loss: 1.9208 - learning_rate: 1.0000e-04
# Epoch 5/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3453 - loss: 1.9933
# Epoch 5: val_accuracy improved from 0.38933 to 0.42027, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 81s 153ms/step - accuracy: 0.3453 - loss: 1.9933 - val_accuracy: 0.4203 - val_loss: 1.8023 - learning_rate: 1.0000e-04
# Epoch 6/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3684 - loss: 1.9651
# Epoch 6: val_accuracy did not improve from 0.42027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.3684 - loss: 1.9651 - val_accuracy: 0.4203 - val_loss: 1.8086 - learning_rate: 1.0000e-04
# Epoch 7/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3596 - loss: 1.9524
# Epoch 7: val_accuracy did not improve from 0.42027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.3596 - loss: 1.9524 - val_accuracy: 0.4064 - val_loss: 1.9022 - learning_rate: 1.0000e-04
# Epoch 8/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3637 - loss: 1.9594
# Epoch 8: val_accuracy improved from 0.42027 to 0.42880, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 83s 157ms/step - accuracy: 0.3637 - loss: 1.9593 - val_accuracy: 0.4288 - val_loss: 1.7544 - learning_rate: 1.0000e-04
# Epoch 9/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3825 - loss: 1.8935
# Epoch 9: val_accuracy improved from 0.42880 to 0.43467, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 85s 160ms/step - accuracy: 0.3825 - loss: 1.8936 - val_accuracy: 0.4347 - val_loss: 1.7143 - learning_rate: 1.0000e-04
# Epoch 10/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3672 - loss: 1.9038
# Epoch 10: val_accuracy did not improve from 0.43467
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 136s 257ms/step - accuracy: 0.3673 - loss: 1.9038 - val_accuracy: 0.4336 - val_loss: 1.8160 - learning_rate: 1.0000e-04
# Epoch 11/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3828 - loss: 1.8673
# Epoch 11: val_accuracy did not improve from 0.43467
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.3828 - loss: 1.8674 - val_accuracy: 0.4245 - val_loss: 1.7163 - learning_rate: 1.0000e-04
# Epoch 12/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3848 - loss: 1.8706
# Epoch 12: val_accuracy did not improve from 0.43467
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.3848 - loss: 1.8706 - val_accuracy: 0.4155 - val_loss: 1.8096 - learning_rate: 1.0000e-04
# Epoch 13/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3888 - loss: 1.8684
# Epoch 13: val_accuracy improved from 0.43467 to 0.45120, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 81s 153ms/step - accuracy: 0.3888 - loss: 1.8684 - val_accuracy: 0.4512 - val_loss: 1.8813 - learning_rate: 1.0000e-04
# Epoch 14/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3973 - loss: 1.8414
# Epoch 14: val_accuracy improved from 0.45120 to 0.45547, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 83s 157ms/step - accuracy: 0.3973 - loss: 1.8414 - val_accuracy: 0.4555 - val_loss: 1.7317 - learning_rate: 1.0000e-04
# Epoch 15/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.3890 - loss: 1.8414
# Epoch 15: val_accuracy did not improve from 0.45547
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 151ms/step - accuracy: 0.3890 - loss: 1.8414 - val_accuracy: 0.4448 - val_loss: 1.7473 - learning_rate: 1.0000e-04
# Epoch 16/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3997 - loss: 1.8491
# Epoch 16: val_accuracy did not improve from 0.45547
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.3997 - loss: 1.8491 - val_accuracy: 0.4485 - val_loss: 1.6911 - learning_rate: 1.0000e-04
# Epoch 17/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4022 - loss: 1.8421
# Epoch 17: val_accuracy improved from 0.45547 to 0.46933, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 84s 160ms/step - accuracy: 0.4022 - loss: 1.8421 - val_accuracy: 0.4693 - val_loss: 1.6548 - learning_rate: 1.0000e-04
# Epoch 18/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.3907 - loss: 1.8722
# Epoch 18: val_accuracy improved from 0.46933 to 0.48640, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 81s 153ms/step - accuracy: 0.3907 - loss: 1.8722 - val_accuracy: 0.4864 - val_loss: 1.6745 - learning_rate: 1.0000e-04
# Epoch 19/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3967 - loss: 1.8376
# Epoch 19: val_accuracy did not improve from 0.48640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.3967 - loss: 1.8376 - val_accuracy: 0.4069 - val_loss: 1.7671 - learning_rate: 1.0000e-04
# Epoch 20/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4049 - loss: 1.8111
# Epoch 20: val_accuracy did not improve from 0.48640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 82s 156ms/step - accuracy: 0.4049 - loss: 1.8111 - val_accuracy: 0.4512 - val_loss: 1.6573 - learning_rate: 1.0000e-04
# Epoch 21/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4054 - loss: 1.8296
# Epoch 21: val_accuracy did not improve from 0.48640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.4054 - loss: 1.8296 - val_accuracy: 0.4251 - val_loss: 1.7891 - learning_rate: 1.0000e-04
# Epoch 22/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4075 - loss: 1.8321
# Epoch 22: val_accuracy did not improve from 0.48640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 147ms/step - accuracy: 0.4075 - loss: 1.8320 - val_accuracy: 0.4603 - val_loss: 1.6605 - learning_rate: 1.0000e-04
# Epoch 23/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4081 - loss: 1.8293
# Epoch 23: val_accuracy did not improve from 0.48640
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.4081 - loss: 1.8293 - val_accuracy: 0.4501 - val_loss: 1.6725 - learning_rate: 1.0000e-04
# Epoch 24/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4097 - loss: 1.7652
# Epoch 24: val_accuracy did not improve from 0.48640
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 82s 155ms/step - accuracy: 0.4098 - loss: 1.7651 - val_accuracy: 0.4395 - val_loss: 1.6861 - learning_rate: 5.0000e-05
# Epoch 25/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4237 - loss: 1.7152
# Epoch 25: val_accuracy improved from 0.48640 to 0.48960, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 85s 161ms/step - accuracy: 0.4237 - loss: 1.7152 - val_accuracy: 0.4896 - val_loss: 1.5702 - learning_rate: 5.0000e-05
# Epoch 26/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4354 - loss: 1.6990
# Epoch 26: val_accuracy did not improve from 0.48960
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 135s 255ms/step - accuracy: 0.4354 - loss: 1.6990 - val_accuracy: 0.4715 - val_loss: 1.6155 - learning_rate: 5.0000e-05
# Epoch 27/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4324 - loss: 1.7159
# Epoch 27: val_accuracy improved from 0.48960 to 0.49067, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 83s 158ms/step - accuracy: 0.4324 - loss: 1.7159 - val_accuracy: 0.4907 - val_loss: 1.5837 - learning_rate: 5.0000e-05
# Epoch 28/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4431 - loss: 1.6860
# Epoch 28: val_accuracy did not improve from 0.49067
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.4431 - loss: 1.6860 - val_accuracy: 0.4523 - val_loss: 1.6907 - learning_rate: 5.0000e-05
# Epoch 29/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4391 - loss: 1.7060
# Epoch 29: val_accuracy improved from 0.49067 to 0.50293, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 92s 175ms/step - accuracy: 0.4391 - loss: 1.7060 - val_accuracy: 0.5029 - val_loss: 1.6089 - learning_rate: 5.0000e-05
# Epoch 30/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4491 - loss: 1.6725
# Epoch 30: val_accuracy improved from 0.50293 to 0.51573, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 89s 168ms/step - accuracy: 0.4491 - loss: 1.6726 - val_accuracy: 0.5157 - val_loss: 1.5599 - learning_rate: 5.0000e-05
# Epoch 31/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4469 - loss: 1.6887
# Epoch 31: val_accuracy did not improve from 0.51573
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.4469 - loss: 1.6887 - val_accuracy: 0.4917 - val_loss: 1.5625 - learning_rate: 5.0000e-05
# Epoch 32/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4463 - loss: 1.6996
# Epoch 32: val_accuracy did not improve from 0.51573
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 82s 156ms/step - accuracy: 0.4463 - loss: 1.6995 - val_accuracy: 0.5061 - val_loss: 1.6905 - learning_rate: 5.0000e-05
# Epoch 33/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4474 - loss: 1.6900
# Epoch 33: val_accuracy did not improve from 0.51573
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 82s 155ms/step - accuracy: 0.4474 - loss: 1.6900 - val_accuracy: 0.5104 - val_loss: 1.5415 - learning_rate: 5.0000e-05
# Epoch 34/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4508 - loss: 1.6649
# Epoch 34: val_accuracy did not improve from 0.51573
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.4508 - loss: 1.6648 - val_accuracy: 0.5093 - val_loss: 1.6344 - learning_rate: 5.0000e-05
# Epoch 35/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4482 - loss: 1.6873
# Epoch 35: val_accuracy did not improve from 0.51573
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.4482 - loss: 1.6873 - val_accuracy: 0.4864 - val_loss: 1.5797 - learning_rate: 5.0000e-05
# Epoch 36/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4634 - loss: 1.6446
# Epoch 36: val_accuracy did not improve from 0.51573
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.4634 - loss: 1.6446 - val_accuracy: 0.4971 - val_loss: 1.5100 - learning_rate: 2.5000e-05
# Epoch 37/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4711 - loss: 1.5865
# Epoch 37: val_accuracy improved from 0.51573 to 0.51733, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 92s 175ms/step - accuracy: 0.4711 - loss: 1.5866 - val_accuracy: 0.5173 - val_loss: 1.5140 - learning_rate: 2.5000e-05
# Epoch 38/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4666 - loss: 1.5932
# Epoch 38: val_accuracy improved from 0.51733 to 0.53493, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 84s 160ms/step - accuracy: 0.4666 - loss: 1.5932 - val_accuracy: 0.5349 - val_loss: 1.4852 - learning_rate: 2.5000e-05
# Epoch 39/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4814 - loss: 1.5832
# Epoch 39: val_accuracy did not improve from 0.53493
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.4814 - loss: 1.5832 - val_accuracy: 0.5333 - val_loss: 1.4796 - learning_rate: 2.5000e-05
# Epoch 40/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4693 - loss: 1.5850
# Epoch 40: val_accuracy did not improve from 0.53493
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.4693 - loss: 1.5850 - val_accuracy: 0.5205 - val_loss: 1.5161 - learning_rate: 2.5000e-05
# Epoch 41/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4801 - loss: 1.5745
# Epoch 41: val_accuracy did not improve from 0.53493
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.4801 - loss: 1.5745 - val_accuracy: 0.5312 - val_loss: 1.4807 - learning_rate: 2.5000e-05
# Epoch 42/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4818 - loss: 1.5710
# Epoch 42: val_accuracy did not improve from 0.53493
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 147ms/step - accuracy: 0.4818 - loss: 1.5711 - val_accuracy: 0.5141 - val_loss: 1.4807 - learning_rate: 2.5000e-05
# Epoch 43/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4770 - loss: 1.5902
# Epoch 43: val_accuracy did not improve from 0.53493
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.4771 - loss: 1.5902 - val_accuracy: 0.5211 - val_loss: 1.4693 - learning_rate: 2.5000e-05
# Epoch 44/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4925 - loss: 1.5171
# Epoch 44: val_accuracy did not improve from 0.53493
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.4925 - loss: 1.5171 - val_accuracy: 0.5237 - val_loss: 1.4652 - learning_rate: 1.2500e-05
# Epoch 45/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4954 - loss: 1.5559
# Epoch 45: val_accuracy improved from 0.53493 to 0.54240, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 84s 159ms/step - accuracy: 0.4954 - loss: 1.5558 - val_accuracy: 0.5424 - val_loss: 1.4461 - learning_rate: 1.2500e-05
# Epoch 46/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5010 - loss: 1.5111
# Epoch 46: val_accuracy did not improve from 0.54240
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 149ms/step - accuracy: 0.5010 - loss: 1.5111 - val_accuracy: 0.5397 - val_loss: 1.4499 - learning_rate: 1.2500e-05
# Epoch 47/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4908 - loss: 1.5137
# Epoch 47: val_accuracy did not improve from 0.54240
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 82s 155ms/step - accuracy: 0.4908 - loss: 1.5137 - val_accuracy: 0.5424 - val_loss: 1.4471 - learning_rate: 1.2500e-05
# Epoch 48/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5069 - loss: 1.5012
# Epoch 48: val_accuracy did not improve from 0.54240
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.5069 - loss: 1.5012 - val_accuracy: 0.5349 - val_loss: 1.4426 - learning_rate: 1.2500e-05
# Epoch 49/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5017 - loss: 1.5213
# Epoch 49: val_accuracy improved from 0.54240 to 0.54347, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 85s 160ms/step - accuracy: 0.5017 - loss: 1.5212 - val_accuracy: 0.5435 - val_loss: 1.4420 - learning_rate: 1.2500e-05
# Epoch 50/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5096 - loss: 1.5029
# Epoch 50: val_accuracy improved from 0.54347 to 0.55680, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 90s 170ms/step - accuracy: 0.5096 - loss: 1.5029 - val_accuracy: 0.5568 - val_loss: 1.4203 - learning_rate: 1.2500e-05
# Epoch 51/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5089 - loss: 1.4891
# Epoch 51: val_accuracy did not improve from 0.55680
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 132s 250ms/step - accuracy: 0.5089 - loss: 1.4891 - val_accuracy: 0.5488 - val_loss: 1.4191 - learning_rate: 1.2500e-05
# Epoch 52/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5108 - loss: 1.4687
# Epoch 52: val_accuracy did not improve from 0.55680
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.5108 - loss: 1.4687 - val_accuracy: 0.5520 - val_loss: 1.4125 - learning_rate: 1.2500e-05
# Epoch 53/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5097 - loss: 1.4686
# Epoch 53: val_accuracy improved from 0.55680 to 0.56320, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 81s 153ms/step - accuracy: 0.5097 - loss: 1.4686 - val_accuracy: 0.5632 - val_loss: 1.4026 - learning_rate: 1.2500e-05
# Epoch 54/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5138 - loss: 1.4620
# Epoch 54: val_accuracy did not improve from 0.56320
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.5138 - loss: 1.4620 - val_accuracy: 0.5579 - val_loss: 1.3999 - learning_rate: 1.2500e-05
# Epoch 55/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5145 - loss: 1.4485
# Epoch 55: val_accuracy did not improve from 0.56320
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.5145 - loss: 1.4486 - val_accuracy: 0.5456 - val_loss: 1.4452 - learning_rate: 1.2500e-05
# Epoch 56/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5192 - loss: 1.4416
# Epoch 56: val_accuracy improved from 0.56320 to 0.57440, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 81s 153ms/step - accuracy: 0.5192 - loss: 1.4416 - val_accuracy: 0.5744 - val_loss: 1.3805 - learning_rate: 1.2500e-05
# Epoch 57/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5282 - loss: 1.4399
# Epoch 57: val_accuracy did not improve from 0.57440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.5282 - loss: 1.4399 - val_accuracy: 0.5621 - val_loss: 1.3907 - learning_rate: 1.2500e-05
# Epoch 58/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5285 - loss: 1.4328
# Epoch 58: val_accuracy did not improve from 0.57440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.5285 - loss: 1.4328 - val_accuracy: 0.5632 - val_loss: 1.3831 - learning_rate: 1.2500e-05
# Epoch 59/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5329 - loss: 1.4402
# Epoch 59: val_accuracy did not improve from 0.57440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.5329 - loss: 1.4402 - val_accuracy: 0.5680 - val_loss: 1.4044 - learning_rate: 1.2500e-05
# Epoch 60/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5306 - loss: 1.4198
# Epoch 60: val_accuracy did not improve from 0.57440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 147ms/step - accuracy: 0.5306 - loss: 1.4198 - val_accuracy: 0.5712 - val_loss: 1.3871 - learning_rate: 1.2500e-05
# Epoch 61/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5344 - loss: 1.4329
# Epoch 61: val_accuracy improved from 0.57440 to 0.57707, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 87s 165ms/step - accuracy: 0.5344 - loss: 1.4329 - val_accuracy: 0.5771 - val_loss: 1.3562 - learning_rate: 1.2500e-05
# Epoch 62/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5305 - loss: 1.4376
# Epoch 62: val_accuracy improved from 0.57707 to 0.57973, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 84s 160ms/step - accuracy: 0.5305 - loss: 1.4376 - val_accuracy: 0.5797 - val_loss: 1.3700 - learning_rate: 1.2500e-05
# Epoch 63/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5390 - loss: 1.3986
# Epoch 63: val_accuracy did not improve from 0.57973
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.5390 - loss: 1.3986 - val_accuracy: 0.5797 - val_loss: 1.3681 - learning_rate: 1.2500e-05
# Epoch 64/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5394 - loss: 1.3949
# Epoch 64: val_accuracy improved from 0.57973 to 0.58187, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 92s 175ms/step - accuracy: 0.5394 - loss: 1.3949 - val_accuracy: 0.5819 - val_loss: 1.3529 - learning_rate: 1.2500e-05
# Epoch 65/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5384 - loss: 1.4271
# Epoch 65: val_accuracy did not improve from 0.58187
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 149ms/step - accuracy: 0.5384 - loss: 1.4271 - val_accuracy: 0.5733 - val_loss: 1.3808 - learning_rate: 1.2500e-05
# Epoch 66/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5432 - loss: 1.4190
# Epoch 66: val_accuracy improved from 0.58187 to 0.59093, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 89s 169ms/step - accuracy: 0.5432 - loss: 1.4190 - val_accuracy: 0.5909 - val_loss: 1.3368 - learning_rate: 1.2500e-05
# Epoch 67/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5440 - loss: 1.3997
# Epoch 67: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.5440 - loss: 1.3997 - val_accuracy: 0.5899 - val_loss: 1.3583 - learning_rate: 1.2500e-05
# Epoch 68/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5404 - loss: 1.4259
# Epoch 68: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 149ms/step - accuracy: 0.5404 - loss: 1.4259 - val_accuracy: 0.5877 - val_loss: 1.3475 - learning_rate: 1.2500e-05
# Epoch 69/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5463 - loss: 1.4036
# Epoch 69: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.5463 - loss: 1.4036 - val_accuracy: 0.5877 - val_loss: 1.3414 - learning_rate: 1.2500e-05
# Epoch 70/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5426 - loss: 1.3935
# Epoch 70: val_accuracy did not improve from 0.59093
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 147ms/step - accuracy: 0.5426 - loss: 1.3935 - val_accuracy: 0.5835 - val_loss: 1.3416 - learning_rate: 1.2500e-05
# Epoch 71/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5483 - loss: 1.3848
# Epoch 71: val_accuracy did not improve from 0.59093
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.5483 - loss: 1.3848 - val_accuracy: 0.5883 - val_loss: 1.3337 - learning_rate: 1.2500e-05
# Epoch 72/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5501 - loss: 1.3801
# Epoch 72: val_accuracy improved from 0.59093 to 0.59200, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 90s 170ms/step - accuracy: 0.5501 - loss: 1.3801 - val_accuracy: 0.5920 - val_loss: 1.3336 - learning_rate: 6.2500e-06
# Epoch 73/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5605 - loss: 1.3579
# Epoch 73: val_accuracy did not improve from 0.59200
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 131s 248ms/step - accuracy: 0.5605 - loss: 1.3578 - val_accuracy: 0.5872 - val_loss: 1.3212 - learning_rate: 6.2500e-06
# Epoch 74/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5651 - loss: 1.3383
# Epoch 74: val_accuracy did not improve from 0.59200
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.5651 - loss: 1.3383 - val_accuracy: 0.5909 - val_loss: 1.3203 - learning_rate: 6.2500e-06
# Epoch 75/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5602 - loss: 1.3742
# Epoch 75: val_accuracy improved from 0.59200 to 0.59840, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 81s 154ms/step - accuracy: 0.5602 - loss: 1.3742 - val_accuracy: 0.5984 - val_loss: 1.3210 - learning_rate: 6.2500e-06
# Epoch 76/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5633 - loss: 1.3346
# Epoch 76: val_accuracy did not improve from 0.59840
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 80s 151ms/step - accuracy: 0.5633 - loss: 1.3346 - val_accuracy: 0.5909 - val_loss: 1.3374 - learning_rate: 6.2500e-06
# Epoch 77/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5722 - loss: 1.3221
# Epoch 77: val_accuracy did not improve from 0.59840
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.5721 - loss: 1.3221 - val_accuracy: 0.5952 - val_loss: 1.3166 - learning_rate: 6.2500e-06
# Epoch 78/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5646 - loss: 1.3392
# Epoch 78: val_accuracy improved from 0.59840 to 0.60427, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 84s 159ms/step - accuracy: 0.5646 - loss: 1.3392 - val_accuracy: 0.6043 - val_loss: 1.3098 - learning_rate: 6.2500e-06
# Epoch 79/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5623 - loss: 1.3378
# Epoch 79: val_accuracy did not improve from 0.60427
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 136s 258ms/step - accuracy: 0.5623 - loss: 1.3378 - val_accuracy: 0.6027 - val_loss: 1.3152 - learning_rate: 6.2500e-06
# Epoch 80/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5602 - loss: 1.3447
# Epoch 80: val_accuracy improved from 0.60427 to 0.60800, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 82s 154ms/step - accuracy: 0.5602 - loss: 1.3447 - val_accuracy: 0.6080 - val_loss: 1.3128 - learning_rate: 6.2500e-06
# Epoch 81/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5726 - loss: 1.3360
# Epoch 81: val_accuracy did not improve from 0.60800
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.5726 - loss: 1.3360 - val_accuracy: 0.5979 - val_loss: 1.3028 - learning_rate: 6.2500e-06
# Epoch 82/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5708 - loss: 1.3247
# Epoch 82: val_accuracy improved from 0.60800 to 0.61333, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 81s 154ms/step - accuracy: 0.5708 - loss: 1.3247 - val_accuracy: 0.6133 - val_loss: 1.2957 - learning_rate: 6.2500e-06
# Epoch 83/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5764 - loss: 1.3040
# Epoch 83: val_accuracy did not improve from 0.61333
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.5763 - loss: 1.3040 - val_accuracy: 0.6016 - val_loss: 1.2906 - learning_rate: 6.2500e-06
# Epoch 84/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5728 - loss: 1.3125
# Epoch 84: val_accuracy did not improve from 0.61333
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.5728 - loss: 1.3125 - val_accuracy: 0.6117 - val_loss: 1.3026 - learning_rate: 6.2500e-06
# Epoch 85/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5742 - loss: 1.2951
# Epoch 85: val_accuracy did not improve from 0.61333
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 82s 155ms/step - accuracy: 0.5742 - loss: 1.2952 - val_accuracy: 0.6053 - val_loss: 1.2984 - learning_rate: 6.2500e-06
# Epoch 86/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5744 - loss: 1.2951
# Epoch 86: val_accuracy improved from 0.61333 to 0.62027, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 86s 163ms/step - accuracy: 0.5744 - loss: 1.2951 - val_accuracy: 0.6203 - val_loss: 1.2941 - learning_rate: 6.2500e-06
# Epoch 87/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5719 - loss: 1.3042
# Epoch 87: val_accuracy did not improve from 0.62027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 149ms/step - accuracy: 0.5719 - loss: 1.3042 - val_accuracy: 0.6128 - val_loss: 1.3004 - learning_rate: 6.2500e-06
# Epoch 88/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5827 - loss: 1.2937
# Epoch 88: val_accuracy did not improve from 0.62027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.5827 - loss: 1.2937 - val_accuracy: 0.6053 - val_loss: 1.3033 - learning_rate: 6.2500e-06
# Epoch 89/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5702 - loss: 1.3076
# Epoch 89: val_accuracy did not improve from 0.62027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.5702 - loss: 1.3076 - val_accuracy: 0.6128 - val_loss: 1.2865 - learning_rate: 6.2500e-06
# Epoch 90/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5890 - loss: 1.2630
# Epoch 90: val_accuracy did not improve from 0.62027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.5890 - loss: 1.2631 - val_accuracy: 0.6080 - val_loss: 1.2917 - learning_rate: 6.2500e-06
# Epoch 91/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5838 - loss: 1.2844
# Epoch 91: val_accuracy did not improve from 0.62027
#
# Epoch 91: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.5838 - loss: 1.2844 - val_accuracy: 0.6165 - val_loss: 1.2877 - learning_rate: 6.2500e-06
# Epoch 92/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5896 - loss: 1.2539
# Epoch 92: val_accuracy improved from 0.62027 to 0.62293, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 90s 171ms/step - accuracy: 0.5896 - loss: 1.2540 - val_accuracy: 0.6229 - val_loss: 1.2690 - learning_rate: 3.1250e-06
# Epoch 93/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5794 - loss: 1.3038
# Epoch 93: val_accuracy did not improve from 0.62293
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.5794 - loss: 1.3037 - val_accuracy: 0.6133 - val_loss: 1.2784 - learning_rate: 3.1250e-06
# Epoch 94/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5887 - loss: 1.2798
# Epoch 94: val_accuracy did not improve from 0.62293
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.5887 - loss: 1.2798 - val_accuracy: 0.6165 - val_loss: 1.2873 - learning_rate: 3.1250e-06
# Epoch 95/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5944 - loss: 1.2495
# Epoch 95: val_accuracy improved from 0.62293 to 0.62400, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 82s 155ms/step - accuracy: 0.5944 - loss: 1.2495 - val_accuracy: 0.6240 - val_loss: 1.2748 - learning_rate: 3.1250e-06
# Epoch 96/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5876 - loss: 1.2496
# Epoch 96: val_accuracy did not improve from 0.62400
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 150ms/step - accuracy: 0.5876 - loss: 1.2496 - val_accuracy: 0.6203 - val_loss: 1.2697 - learning_rate: 3.1250e-06
# Epoch 97/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5997 - loss: 1.2427
# Epoch 97: val_accuracy did not improve from 0.62400
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 78s 148ms/step - accuracy: 0.5997 - loss: 1.2428 - val_accuracy: 0.6219 - val_loss: 1.2727 - learning_rate: 3.1250e-06
# Epoch 98/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5952 - loss: 1.2500
# Epoch 98: val_accuracy did not improve from 0.62400
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 79s 149ms/step - accuracy: 0.5952 - loss: 1.2500 - val_accuracy: 0.6219 - val_loss: 1.2692 - learning_rate: 3.1250e-06
# Epoch 99/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5909 - loss: 1.2562
# Epoch 99: val_accuracy improved from 0.62400 to 0.62613, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 85s 161ms/step - accuracy: 0.5909 - loss: 1.2562 - val_accuracy: 0.6261 - val_loss: 1.2679 - learning_rate: 3.1250e-06
# Epoch 100/100
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5966 - loss: 1.2538
# Epoch 100: val_accuracy improved from 0.62613 to 0.62720, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 86s 162ms/step - accuracy: 0.5966 - loss: 1.2538 - val_accuracy: 0.6272 - val_loss: 1.2638 - learning_rate: 3.1250e-06
# Best validation model: epoch 100  - val_accuracy 0.6272000074386597

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np

model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 62.720%
# Mean Recall: 54.176%
# Mean Precision: 63.059%
# > Cargo plane: Recall: 71.186% Precision: 97.674% Specificity: 99.945% Dice: 82.353%
# > Small car: Recall: 85.106% Precision: 64.965% Specificity: 90.233% Dice: 73.684%
# > Bus: Recall: 62.644% Precision: 53.431% Specificity: 94.415% Dice: 57.672%
# > Truck: Recall: 32.365% Precision: 42.391% Specificity: 93.513% Dice: 36.706%
# > Motorboat: Recall: 44.037% Precision: 69.565% Specificity: 98.811% Dice: 53.933%
# > Fishing vessel: Recall: 64.384% Precision: 87.037% Specificity: 99.612% Dice: 74.016%
# > Dump truck: Recall: 41.525% Precision: 53.846% Specificity: 97.610% Dice: 46.890%
# > Excavator: Recall: 58.025% Precision: 62.667% Specificity: 98.439% Dice: 60.256%
# > Building: Recall: 85.675% Precision: 65.474% Specificity: 89.153% Dice: 74.224%
# > Helipad: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Storage tank: Recall: 46.053% Precision: 76.923% Specificity: 98.781% Dice: 57.613%
# > Shipping container: Recall: 57.037% Precision: 55.797% Specificity: 96.494% Dice: 56.410%
# > Pylon: Recall: 56.250% Precision: 90.000% Specificity: 99.891% Dice: 69.231%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
anns = []
# The "xview_recognition" folder ends at index 83 in this specific Kaggle path
# But it's safer to just look for the word "xview_test"
base_folder = '/content/dl_data/xview_recognition/'

for (dirpath, dirnames, filenames) in os.walk(base_folder + 'xview_test'):
    for filename in filenames:
        # Get the path relative to the 'xview_recognition' folder
        # This will result in: 'xview_test/filename.tif' or 'xview_test/category/filename.tif'
        rel_path = os.path.relpath(os.path.join(dirpath, filename), base_folder)

        image = GenericImage(rel_path)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = os.path.basename(dirpath)
        image.add_object(obj)
        anns.append(image)

print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("model2_1run.json", "w") as outfile:
    json.dump(predictions_data, outfile)

# %%
with open("/content/drive/MyDrive/Projects Data/Results/model2_1run.json", "w") as outfile:
    json.dump(predictions_data, outfile)
